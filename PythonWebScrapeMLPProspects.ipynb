# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.mlb.com/prospects'

page = requests.get(url)

Soup = BeautifulSoup(page.text, 'html')

# %%
print(Soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>Top 100 Baseball Prospects | MLB.com</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="The Official Site of Major League Baseball" name="description"/>
# <meta content="The Official Site of Major League Baseball" property="og:description"/>
# <meta content="Top 100 Baseball Prospects" property="og:title"/>
# <meta content="https://images.ctfassets.net/iiozhi00a8lc/6eVNaWkMqOisIOvq9HWPM5/2a85d46da715dd9b59a185a1972cc2f7/2568x1444_share_Pipeline.jpg" property="og:image"/>
# <meta content="MLB.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.mlb.com/prospects" property="og:url"/>
# ...

# %%
Soup.find('table')
# Out:
# <table class="rankings__table rankings__table--top100" data-testid="rankings__table"><thead><tr><th aria-sort="ascending" class="rankings__table__cell--rank"><button aria-pressed="true" class="Styles__SortingButton-sc-1du4v6x-1 ePqIdC">Rank<span aria-hidden="true"><svg aria-labelledby="title-arrow-up-101256 desc-arrow-up-101256" class="p-icon p-icon--arrow-up Styles__SortIcon-sc-1du4v6x-2 DEoIF" height="16" role="img" viewbox="0 0 470 279" width="16"><title id="title-arrow-up-101256"></title><desc id="desc-arrow-up-101256"></desc><path d="M203.814 13.497c17.18-17.996 45.007-17.996 62.218 0L456.5 213.443c17.21 18.027 24.81 65.252-29.572 65.252H42.858c-56.215 0-46.78-47.194-29.57-65.252L203.813 13.497z" fill="#010201" fill-rule="evenodd"></path></svg></span></button></th><th class="rankings__table__cell--player">Player</th><th class="rankings__table__cell--position">Position</th><th class="rankings__table__cell--team">Team</th><th class="rankings__table__cell--level"><button aria-press
# ...

# %%
Soup.find_all('table')[0]
# Out:
# <table class="rankings__table rankings__table--top100" data-testid="rankings__table"><thead><tr><th aria-sort="ascending" class="rankings__table__cell--rank"><button aria-pressed="true" class="Styles__SortingButton-sc-1du4v6x-1 ePqIdC">Rank<span aria-hidden="true"><svg aria-labelledby="title-arrow-up-101256 desc-arrow-up-101256" class="p-icon p-icon--arrow-up Styles__SortIcon-sc-1du4v6x-2 DEoIF" height="16" role="img" viewbox="0 0 470 279" width="16"><title id="title-arrow-up-101256"></title><desc id="desc-arrow-up-101256"></desc><path d="M203.814 13.497c17.18-17.996 45.007-17.996 62.218 0L456.5 213.443c17.21 18.027 24.81 65.252-29.572 65.252H42.858c-56.215 0-46.78-47.194-29.57-65.252L203.813 13.497z" fill="#010201" fill-rule="evenodd"></path></svg></span></button></th><th class="rankings__table__cell--player">Player</th><th class="rankings__table__cell--position">Position</th><th class="rankings__table__cell--team">Team</th><th class="rankings__table__cell--level"><button aria-press
# ...

# %%
Soup.find('table', class_ = 'rankings__table rankings__table--top100')
# Out:
# <table class="rankings__table rankings__table--top100" data-testid="rankings__table"><thead><tr><th aria-sort="ascending" class="rankings__table__cell--rank"><button aria-pressed="true" class="Styles__SortingButton-sc-1du4v6x-1 ePqIdC">Rank<span aria-hidden="true"><svg aria-labelledby="title-arrow-up-101256 desc-arrow-up-101256" class="p-icon p-icon--arrow-up Styles__SortIcon-sc-1du4v6x-2 DEoIF" height="16" role="img" viewbox="0 0 470 279" width="16"><title id="title-arrow-up-101256"></title><desc id="desc-arrow-up-101256"></desc><path d="M203.814 13.497c17.18-17.996 45.007-17.996 62.218 0L456.5 213.443c17.21 18.027 24.81 65.252-29.572 65.252H42.858c-56.215 0-46.78-47.194-29.57-65.252L203.813 13.497z" fill="#010201" fill-rule="evenodd"></path></svg></span></button></th><th class="rankings__table__cell--player">Player</th><th class="rankings__table__cell--position">Position</th><th class="rankings__table__cell--team">Team</th><th class="rankings__table__cell--level"><button aria-press
# ...

# %%
table = Soup.find_all('table')[0]

# %%
print(table)
# Out:
# <table class="rankings__table rankings__table--top100" data-testid="rankings__table"><thead><tr><th aria-sort="ascending" class="rankings__table__cell--rank"><button aria-pressed="true" class="Styles__SortingButton-sc-1du4v6x-1 ePqIdC">Rank<span aria-hidden="true"><svg aria-labelledby="title-arrow-up-101256 desc-arrow-up-101256" class="p-icon p-icon--arrow-up Styles__SortIcon-sc-1du4v6x-2 DEoIF" height="16" role="img" viewbox="0 0 470 279" width="16"><title id="title-arrow-up-101256"></title><desc id="desc-arrow-up-101256"></desc><path d="M203.814 13.497c17.18-17.996 45.007-17.996 62.218 0L456.5 213.443c17.21 18.027 24.81 65.252-29.572 65.252H42.858c-56.215 0-46.78-47.194-29.57-65.252L203.813 13.497z" fill="#010201" fill-rule="evenodd"></path></svg></span></button></th><th class="rankings__table__cell--player">Player</th><th class="rankings__table__cell--position">Position</th><th class="rankings__table__cell--team">Team</th><th class="rankings__table__cell--level"><button aria-press
# ...

# %%
Soup.find_all('th')
# Out:
# [<th aria-sort="ascending" class="rankings__table__cell--rank"><button aria-pressed="true" class="Styles__SortingButton-sc-1du4v6x-1 ePqIdC">Rank<span aria-hidden="true"><svg aria-labelledby="title-arrow-up-101256 desc-arrow-up-101256" class="p-icon p-icon--arrow-up Styles__SortIcon-sc-1du4v6x-2 DEoIF" height="16" role="img" viewbox="0 0 470 279" width="16"><title id="title-arrow-up-101256"></title><desc id="desc-arrow-up-101256"></desc><path d="M203.814 13.497c17.18-17.996 45.007-17.996 62.218 0L456.5 213.443c17.21 18.027 24.81 65.252-29.572 65.252H42.858c-56.215 0-46.78-47.194-29.57-65.252L203.813 13.497z" fill="#010201" fill-rule="evenodd"></path></svg></span></button></th>,
#  <th class="rankings__table__cell--player">Player</th>,
#  <th class="rankings__table__cell--position">Position</th>,
#  <th class="rankings__table__cell--team">Team</th>,
# ...

# %%
world_titles = table.find_all('th')

# %%
world_titles
# Out:
# [<th aria-sort="ascending" class="rankings__table__cell--rank"><button aria-pressed="true" class="Styles__SortingButton-sc-1du4v6x-1 ePqIdC">Rank<span aria-hidden="true"><svg aria-labelledby="title-arrow-up-101256 desc-arrow-up-101256" class="p-icon p-icon--arrow-up Styles__SortIcon-sc-1du4v6x-2 DEoIF" height="16" role="img" viewbox="0 0 470 279" width="16"><title id="title-arrow-up-101256"></title><desc id="desc-arrow-up-101256"></desc><path d="M203.814 13.497c17.18-17.996 45.007-17.996 62.218 0L456.5 213.443c17.21 18.027 24.81 65.252-29.572 65.252H42.858c-56.215 0-46.78-47.194-29.57-65.252L203.813 13.497z" fill="#010201" fill-rule="evenodd"></path></svg></span></button></th>,
#  <th class="rankings__table__cell--player">Player</th>,
#  <th class="rankings__table__cell--position">Position</th>,
#  <th class="rankings__table__cell--team">Team</th>,
# ...

# %%
world_table_titles =[title.text.strip() for title in world_titles]

print(world_table_titles)
# Out:
# ['Rank', 'Player', 'Position', 'Team', 'Level', 'eta', 'Age', 'Height / Weight', 'Bats', 'Throws']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)

df
# Out:
# Empty DataFrame
# Columns: [Rank, Player, Position, Team, Level, eta, Age, Height / Weight, Bats, Throws]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
for row in column_data:
    print(row.find_all('td'))
# Out:
# []
# [<td class="rankings__table__cell--rank" data-testid="table-cell">1</td>, <td class="rankings__table__cell--player" data-testid="table-cell"><div class="prospect-headshot"><a class="styles__StoryContainer-sc-hafij3-0 kkWyqM" href="https://www.mlb.com/stories/jackson-holliday-702616" rel="noreferrer" target="_blank"><div class="sc-dnqmqq hYDEUE headshot-container headshot-container--xs">
# ...

# %%
for row in column_data:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    print(individual_row_data)
# Out:
# []
# ['1', 'Jackson Holliday', 'SS/2B', 'Baltimore Orioles', 'MLB', '2024', '20', '6\' 0" / 185 lbs', 'L', 'R']
# ['2', 'Jackson Chourio', 'OF', 'Milwaukee Brewers', 'MLB', '2024', '20', '6\' 0" / 198 lbs', 'R', 'R']
# ['3', 'Paul Skenes', 'RHP', 'Pittsburgh Pirates', 'AAA', '2024', '21', '6\' 6" / 235 lbs', 'R', 'R']
# ['4', 'Junior Caminero', '3B/SS', 'Tampa Bay Rays', 'AAA', '2024', '20', '6\' 1" / 157 lbs', 'R', 'R']
# ['5', 'Wyatt Langford', 'OF', 'Texas Rangers', 'MLB', '2024', '22', '6\' 0" / 225 lbs', 'R', 'R']

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#   Rank            Player Position                Team Level   eta Age  \
# 0    1  Jackson Holliday    SS/2B   Baltimore Orioles   MLB  2024  20
# 1    2   Jackson Chourio       OF   Milwaukee Brewers   MLB  2024  20
# 2    3       Paul Skenes      RHP  Pittsburgh Pirates   AAA  2024  21
# 3    4   Junior Caminero    3B/SS      Tampa Bay Rays   AAA  2024  20
# 4    5    Wyatt Langford       OF       Texas Rangers   MLB  2024  22
#
#    Height / Weight Bats Throws
# 0  6' 0" / 185 lbs    L      R
# 1  6' 0" / 198 lbs    R      R
# 2  6' 6" / 235 lbs    R      R
# 3  6' 1" / 157 lbs    R      R
# 4  6' 0" / 225 lbs    R      R

# %%
df.to_csv(r'C:\Users\Randy\Desktop\Python Test Folder\MLBProspect.csv')

# %%
df.to_csv(r'C:\Users\Randy\Desktop\Python Test Folder\MLBProspect2.csv', index = False)
